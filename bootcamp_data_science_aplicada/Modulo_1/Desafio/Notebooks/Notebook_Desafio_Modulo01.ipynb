# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolas-stelatto/bootcamp_data_science_aplicada/blob/main/bootcamp_data_science_aplicada/Modulo_1/Desafio/Notebooks/Notebook_Desafio_Modulo01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_dados = "https://github.com/nicolas-stelatto/bootcamp_data_science_aplicada/raw/main/Modulo_1/Desafio/Dados/obitos_por_ano_mes_por_UF.csv"

dados = pd.read_csv(url_dados, sep=";", encoding="ISO-8859-1", engine="python", skiprows=3, skipfooter=11)
dados
# Out:
#       Unidade da Federação  2008/Jan  2008/Fev  ...  2021/Fev  2021/Mar    Total
# 0              11 Rondônia        57        99  ...       333       559    37058
# 1                  12 Acre        30        94  ...       188       205    18615
# 2              13 Amazonas       149       243  ...      1616      1796    64963
# 3               14 Roraima        23        21  ...       322       287    12466
# 4                  15 Pará       543       581  ...      1230      1277   139591
# 5                 16 Amapá        65        81  ...       136       205    13005
# 6             17 Tocantins       141       210  ...         4        52    33714
# 7              21 Maranhão       202       320  ...      1148      1800   113499
# 8                 22 Piauí       224       337  ...       665       697    75742
# 9                 23 Ceará       548      1021  ...      1765      2323   223990
# 10  24 Rio Grande do Norte       204       238  ...       719       639    78673
# ...
